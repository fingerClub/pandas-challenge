# %%
#reading and merging ../Resources/schools_complete.csv and ../Resources/students_complete.csv
import pandas as pd
from pathlib import Path
schoolLoad = Path("../Resources/schools_complete.csv")
studentLoad = Path("../Resources/students_complete.csv")
schDf = pd.read_csv(schoolLoad)
stuDf = pd.read_csv(studentLoad)
df = pd.merge(schDf, stuDf, on="school_name")
df.head(20)
# Out:
#     School ID        school_name      type  size   budget  Student ID  \
# 0           0  Huang High School  District  2917  1910635           0
# 1           0  Huang High School  District  2917  1910635           1
# 2           0  Huang High School  District  2917  1910635           2
# 3           0  Huang High School  District  2917  1910635           3
# 4           0  Huang High School  District  2917  1910635           4
# 5           0  Huang High School  District  2917  1910635           5
# 6           0  Huang High School  District  2917  1910635           6
# 7           0  Huang High School  District  2917  1910635           7
# 8           0  Huang High School  District  2917  1910635           8
# 9           0  Huang High School  District  2917  1910635           9
# 10          0  Huang High School  District  2917  1910635          10
# 11          0  Huang High School  District  2917  1910635          11
# ...

# %%
#finding number of unique schools
uni = df["school_name"].nunique()
uni
# Out:
# 15

# %%
#finding total number of sutdents
stuTot = len(df) - 1
stuTot
# Out:
# 39169

# %%
#finding total budget of schools

uniV = 0
totBud = 0
for x in df["budget"]:
    if x != uniV:
        totBud = totBud + uniV
        uniV = x
totBud
check = df[["School_name"].value_counts()
check
# Out:
# budget
# 3124928    4976
# 3094650    4761
# 3022020    4635
# 2547363    3999
# 1884411    2949
# 1910635    2917
# 1763916    2739
# 1319574    2283
# 1081356    1858
# 1049400    1800
# 1056600    1761
# 1043130    1635
# 917500     1468
# 585858      962
# 248087      427
# Name: count, dtype: int64

# %%
#finding average math score
avgMat = df["math_score"].mean()
matAvg = round(avgMat, 2)
matAvg
# Out:
# 78.99

# %%
# finding average reading score
avgRea = df["reading_score"].mean()
reaAvg = round(avgRea, 2)
reaAvg
# Out:
# 81.88

# %%
#finding percent passed math
matPas = 0
for x in df["math_score"]:
    if x > 69:
        matPas = matPas + 1
matPas = matPas / stuTot * 100
pasMat = round(matPas, 2)  
matPer = f"{pasMat}%"
matPer
# Out:
# '%74.98'

# %%
#finding percent reading
reaPas = 0
for x in df["reading_score"]:
    if x > 69:
        reaPas = reaPas + 1
reaPas = reaPas / stuTot * 100
pasRea = round(reaPas, 2)
reaPer = f"{pasRea}%"
reaPer

# %%
#finding overall passing percent
ovPass = df[(df["math_score"] > 69) & (df["reading_score"] > 69)].count()["Student ID"]
pas = ovPass / stuTot * 100
ovRou = round(pas, 2)
ovPer = f"{ovRou}%"
ovPer

# %%
#creating high-level snapshot of school key metrics in date frame
dist = pd.DataFrame(
    {"unique" : [uniSch],
     "totStuents" : [stuTot],
     "totBudget" : [totBud],
     "avgMath" : [matAvg],
     "avgRead" : [reaAvg],
     "passMath" : [pasMat],
     "passRead" : [pasRea],
     "ovPass" : [ovRou]})
dist.head()
# Out:
#                                               unique  totStuents  totBudget  \
# 0  type
# District    26976
# Charter     12194
# Name:...       39169   23606298
#
#    avgMath  avgRead  passMath  passRead  ovPass
# 0    78.99    81.88     74.98     85.81   65.17

# %%
schf = df["school_name"].value_counts()
schf = schf.reset_index()
schf
# Out:
#               school_name  count
# 0      Bailey High School   4976
# 1     Johnson High School   4761
# 2   Hernandez High School   4635
# 3   Rodriguez High School   3999
# 4    Figueroa High School   2949
# 5       Huang High School   2917
# 6        Ford High School   2739
# 7      Wilson High School   2283
# 8     Cabrera High School   1858
# 9      Wright High School   1800
# 10    Shelton High School   1761
# 11     Thomas High School   1635
# 12    Griffin High School   1468
# 13       Pena High School    962
# 14     Holden High School    427

# %%
typeSch = df.groupby(["school_name"])
